# %% [markdown]
# # Numpy Core Concepts For Data Analysis

# %%
from IPython.display import Image

# %% [markdown]
# ### Array Revisited

# %%
Image(filename='1DArray.jpg')

# %%
Image(filename='2DArray.jpg')

# %%
Image(filename='3DArray.jpg')

# %% [markdown]
# ### Indexing And Slicing

# %%
Image(filename='IndexingAndSlicing.jpg')

# %% [markdown]
# ### Aggregation

# %%
Image(filename='Aggregation.jpg')

# %% [markdown]
# ### Transpoing

# %%
Image(filename='Transposing.jpg')

# %% [markdown]
# ### Reshaping

# %%
Image(filename='Reshaping.jpg')

# %% [markdown]
# # Ways to Create Arrays In Numpy
