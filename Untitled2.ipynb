# %% [markdown]
# # Window Operations

# %%
import pandas as pd

# %%
df=pd.read_csv("Data/globalTemp.csv")
df
# Out:
#        Source        Date    Mean
# 0        GCAG  2016-12-06  0.7895
# 1     GISTEMP  2016-12-06  0.8100
# 2        GCAG  2016-11-06  0.7504
# 3     GISTEMP  2016-11-06  0.9300
# 4        GCAG  2016-10-06  0.7292
# 5     GISTEMP  2016-10-06  0.8900
# 6        GCAG  2016-09-06  0.8767
# 7     GISTEMP  2016-09-06  0.8700
# 8        GCAG  2016-08-06  0.8998
# 9     GISTEMP  2016-08-06  0.9800
# 10       GCAG  2016-07-06  0.8687
# 11    GISTEMP  2016-07-06  0.8300
# 12       GCAG  2016-06-06  0.9006
# 13    GISTEMP  2016-06-06  0.7600
# 14       GCAG  2016-05-06  0.8738
# 15    GISTEMP  2016-05-06  0.9300
# 16       GCAG  2016-04-06  1.0733
# 17    GISTEMP  2016-04-06  1.0900
# 18       GCAG  2016-03-06  1.2245
# 19    GISTEMP  2016-03-06  1.3000
# 20       GCAG  2016-02-06  1.1921
# 21    GISTEMP  2016-02-06  1.3500
# 22       GCAG  2016-01-06  1.0569
# 23    GISTEMP  2016-01-06  1.1700
# 24       GCAG  2015-12-06  1.1219
# 25    GISTEMP  2015-12-06  1.1100
# ...

# %%
df.dtypes
# Out:
# Source     object
# Date       object
# Mean      float64
# dtype: object

# %%
df=df.set_index('Date')
df
# Out:
#              Source    Mean
# Date
# 2016-12-06     GCAG  0.7895
# 2016-12-06  GISTEMP  0.8100
# 2016-11-06     GCAG  0.7504
# 2016-11-06  GISTEMP  0.9300
# 2016-10-06     GCAG  0.7292
# 2016-10-06  GISTEMP  0.8900
# 2016-09-06     GCAG  0.8767
# 2016-09-06  GISTEMP  0.8700
# 2016-08-06     GCAG  0.8998
# 2016-08-06  GISTEMP  0.9800
# 2016-07-06     GCAG  0.8687
# 2016-07-06  GISTEMP  0.8300
# 2016-06-06     GCAG  0.9006
# 2016-06-06  GISTEMP  0.7600
# 2016-05-06     GCAG  0.8738
# 2016-05-06  GISTEMP  0.9300
# 2016-04-06     GCAG  1.0733
# 2016-04-06  GISTEMP  1.0900
# 2016-03-06     GCAG  1.2245
# 2016-03-06  GISTEMP  1.3000
# 2016-02-06     GCAG  1.1921
# 2016-02-06  GISTEMP  1.3500
# 2016-01-06     GCAG  1.0569
# 2016-01-06  GISTEMP  1.1700
# 2015-12-06     GCAG  1.1219
# 2015-12-06  GISTEMP  1.1100
# 2015-11-06     GCAG  0.9655
# 2015-11-06  GISTEMP  1.0400
# 2015-10-06     GCAG  0.9913
# 2015-10-06  GISTEMP  1.0600
# ...             ...     ...
# 1881-03-06     GCAG  0.0348
# ...

# %%
df.index
# Out:
# Index(['2016-12-06', '2016-12-06', '2016-11-06', '2016-11-06', '2016-10-06',
#        '2016-10-06', '2016-09-06', '2016-09-06', '2016-08-06', '2016-08-06',
#        ...
#        '1880-05-06', '1880-05-06', '1880-04-06', '1880-04-06', '1880-03-06',
#        '1880-03-06', '1880-02-06', '1880-02-06', '1880-01-06', '1880-01-06'],
#       dtype='object', name='Date', length=3288)
